# %%
# Bibliotecas 
import pandas as pd
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..", "src")))

# %%
from load_data import read_parquet_pandas
pd.set_option("display.max_rows", None)
missing_report = read_parquet_pandas("reports/missing_report_2025-06-23.parquet")
missing_report = missing_report.sort_values(by='missing_percent', ascending=False)
missing_report
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/06/24 00:29:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/06/24 00:29:10 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
#                                     column_name data_type  missing_count  \
# 1                                     member_id    string        2260701
# 140  orig_projected_additional_accrued_interest    string        2252048
# 131                             hardship_status    string        2249744
# 141              hardship_payoff_balance_amount    string        2249783
# 139                        hardship_loan_status    string        2249777
# ...
