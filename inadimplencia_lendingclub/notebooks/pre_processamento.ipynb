# %% [markdown]
# # 1.1 Carregamento e Visão Geral do Dataset

# %%
# Bibliotecas
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..", "src")))
from spark_session import get_spark_session

spark = get_spark_session()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/06/23 20:41:27 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Carregamento dos dados
from load_data import load_csv_spark

df = load_csv_spark(spark, "data/raw", "accepted_2007_to_2018Q4.csv")

# %%
# Verificação inicial
print(df.show(5))
print(f'O número de registros do dataset é: {df.count()}')
print(f'O número de colunas é: {len(df.columns)}')
print(df.printSchema())
# Out:
# 25/06/23 20:47:45 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# ...

# %%
# Verificando informações sobre valores ausentes/nulos e salvando em um arquivo parquet
from missing_data import missing_report
from load_data import save_parquet_spark

report = missing_report(df)
save_parquet_spark(report, "reports", "missing_report_2025-06-23.parquet")
